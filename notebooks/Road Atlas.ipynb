# %%
import graphviz, IPython

# %%
@IPython.core.magic.register_line_cell_magic
def dot(line, cell):
    return graphviz.Source(cell)

# %%
# %%dot
# digraph G {
#     subgraph cluster_swarm { label=swarm
#         peer -> "another peer" -> peer
#     }
#     subgraph cluster_publisher { label=publisher
#         {mouse keyboard nbformat} -> lab -> nbformat -> dat -> webrtc -> peer -> webrtc
#         subgraph cluster_publisher_secrets { label=secrets "private key" }
#         "public key" -> dat -> "private key"
#         "public key" -> "discovery key" -> "another webrtc" -> "another peer"
#         lab -> {monitor}
#         contents -> nbformat -> contents
#     }
#     subgraph cluster_subscriber { label="minimum subscriber"
#         "subscriber dat" -> "subscriber nbformat"
#         {"subscriber mouse" "subscriber keyboard" "subscriber nbformat"} -> "subscriber lab"
#         "subscriber webrtc" -> peer -> "subscriber webrtc" -> "subscriber dat"
#         "subscriber lab" -> {"subscriber monitor"}
#     }
# }
